# %% [markdown]
# 파이썬에서 프로그래밍을 할때 가장 많이 사용하는 메소드중 하나가 print()일 것이다.<br> print를 다양하게 사용할 수 있지만, 앞으로 자주 사용하는 형태 몇가지를 살펴보자.

# %% [markdown]
# # **colab은 클라우드 버전의 주피터노트북이다.**

# %% [markdown]
# ## 1. 출력

# %% [markdown]
# Jupyter notebook환경에서는 셀의 마지막 줄에 변수명을 올려 놓으면, <br> 그 내용은 **print()메소드를 사용하지 않아도 출력**해준다.

# %%
a=10
a
# Out:
# 10

# %%
a= 5
b= 10
print(a) #마지막 값만 출력해줘서 print 넣어줘야 그 값도 출력가능
a, b
# Out:
# 5
# (5, 10)

# %% [markdown]
# 그러나 다음과 같이 하나의 셀에 여러 개를 출력할 경우에는 print()메소드를 이용하면 된다.
#
# ```
# #문자열의 출력
# print('안녕하세요')
# print('Hello')
# ```

# %%
#문자열의 출력
print('안녕하세요')
print("안녕하세요")
print('"안녕하세요"')
print("'안녕하세요'")
print('Hello')
# Out:
# 안녕하세요
# 안녕하세요
# "안녕하세요"
# '안녕하세요'
# Hello

# %%
mystr = "This is "
print(mystr)
# Out:
# This is

# %%
#숫자의 출력
print(12345678)
# Out:
# 12345678

# %%
#문자열의 출력
num = "12345678"
print(type(num))
# Out:
# <class 'str'>

# %%
a = 12324568
b = "1234567"
type(a), type(b) #변수의 타입을 알려줌

# %% [markdown]
# ## 2. 변수와 대입

# %% [markdown]
# 변수는 **데이터를 담는 그릇**으로 이해하자.
#
# 변수라는 그릇에 정수 또는 문장, file을 담을 수 있는데, <br>이들을 구별하기 위해 변수들에 이름을 부여해야한다.

# %% [markdown]
# ### 2-1. 변수의 이름

# %% [markdown]
# case 1. 알파벳 대소문자와 한글도 가능하다.<br> (한글은 가능하지만 한영변환을 자주해야해서 불편하다.)

# %%
a = 1

# %%
A = 1

# %%
변수 = 1

# %%
변수

# %% [markdown]
# case 2. 알파벳 + 숫자 (가능)

# %%
a1 = 1

# %% [markdown]
# case 3. 알파벳 + 언더바(_) (가능)

# %%
a_ = 1

# %% [markdown]
# case 4. 언더바(_) + 알파벳 (가능))

# %%
_a = 1

# %% [markdown]
# case 5. 숫자 + 알파벳 (숫자로 시작 불가능)

# %%
1a = 1

# %% [markdown]
# case 6. 특수문자 (불가능)

# %%
* = 7

# %% [markdown]
# case 7. 언더바를 제외한 특수문자 (불가능) 언더바는 단어 두개를 붙여서 변수명을 정하고 싶을떄 씀

# %%
a$ = 6

# %% [markdown]
# case 8. 변수의 이름 사이의 공백 (불가능)

# %%
a b = 6

# %% [markdown]
# 주로 변수는 **소문자 알파벳으로 생성**하고, 필요시 **언더바**나 **숫자를 붙히는 방식**이 일반적이다.

# %%
test = 10

# %%
test01 = 20

# %%
test_01 = 30

# %% [markdown]
# **낙타등 표기법(CamelCase)**으로 변수명을 표현하는 것도 좋다

# %%
myData = 30

# %% [markdown]
# ### 2-2. 변수의 출력

# %% [markdown]
# 1. print() 구문 사이에 **값을 직접 집어 넣으면**, 바로 **값이 출력**된다.
# 2. print() 구문 사이에 **변수 이름**을 집어 넣으면, 그 **값이 출력**이 됩니다.

# %%
# 값을 바로 집어 넣은 경우
print('test')
# Out:
# test

# %%
a = 123

# %%
print(a)
# Out:
# 123

# %%
a = '안녕하세요, 반갑습니다'

# %%
print(a)
print(type(a))
# Out:
# 안녕하세요, 반갑습니다
# <class 'str'>

# %%
a= 10
b = 20
result = a+b
#print(result) 끊어서 처리

# %% [markdown]
# # 파이썬의 자료형

# %% [markdown]
# 파이썬은 자료형으로 숫자, 문자, 리스트, 튜플, 딕셔너리, 집합, 불(bool)의 형태를 가지고 있다.

# %% [markdown]
# 이 파일에서는 아래의 순서로 진행한다.
# 1. 숫자(interger(int), float) <br>
# 2. 문자 (string(str)) <br>
# 3. 리스트(List) <br>
# 4. 튜플(Tuple) <br>
# 5. 딕셔너리(Dictionary) <br>
# 6. 집합(set) <br>
# 7. 불(Bool) <br>

# %% [markdown]
# ## 3. 데이터 타입

# %% [markdown]
# **데이터 type**
#
# 1. int(정수)
# 2. float(실수)
# 3. str(문자열)
# 4. bool(참/거짓)

# %% [markdown]
# ### 3-1. int(정수)

# %%
a = 1

# %%
type(a)

# %%
if 1:
    print('1은 참으로 취급')
else:
    print('1은 거짓부렁이')

# %%
if 0:
    print('0은 참으로 취급')
else:
    print('0은 거짓부렁이')

# %%
if 123:
    print('123은 참으로 취급')
else:
    print('123은 거짓부렁이')

# %% [markdown]
# ### 3-2. float(실수)

# %%
a = 3.14

# %%
type(a)

# %%
print(a)

# %% [markdown]
# ### 3-3. str 혹은 object (문자)

# %%
word = '안녕하세요'

# %%
word = "안녕하세요"

# %%
type(word)

# %%
word = "안녕하세요"

# %%
type(word)

# %% [markdown]
# ### 3-4. bool (참/거짓)

# %%
a = False

# %%
print(a)

# %%
0 == False

# %% [markdown]
# ### 3-5 아무것도 아닌 None 타입도 있습니다.

# %% [markdown]
# 말 그래도 아무 것도 아닌 흔히 Null 값을 넣는다고도 합니다.
#
# 사전상 의미는<br>
# * **Null: Nullify (무효화하다)**
# 라는 뜻을 가지고 있다네요~
#
# python에서는 **None** 입니다!

# %%
a = None

# %%
type(a)
# Out:
# NoneType

# %%
print(a)
# Out:
# None

# %% [markdown]
# ## 4. 데이터 타입 (집합)

# %% [markdown]
# **집합 형태의 데이터 타입**
#
# 1. list (순서 O, 집합)
# 2. tuple (순서 O, 읽기 전용 집합)
# 3. set (순서 X(안에 있는지 없는지만 중요), 중복X 집합)
# 4. dict (key, value로 이루어진 사전형 집합)

# %% [markdown]
# ### 4-1. list (순서가 있는 집합)

# %% [markdown]
# [] 형태로 표현합니다.

# %%
mylist = []

# %%
mylist

# %%
type(mylist)

# %%
mylist = [1, 3, 2, 4, 5]

# %%
mylist

# %% [markdown]
# #### 리스트에 추가하기

# %%
mylist = []

# %%
# 비어있는 리스트 확인
mylist

# %%
# mylist를 append함수의 입력으로 받아 리스트에 1을 맨 뒤에 추가
mylist.append(1)

# %%
mylist

# %%
mylist.append(2)
mylist.append(3)

# %%
mylist

# %% [markdown]
# ### myList => "어벤져스", "마이너리티 리포트", "배트맨", "슈퍼맨"

# %%
# 초기화시에 리스트에 입력
myList = ["어벤져스", "마이너리티 리포트", "배트맨", "슈퍼맨"]
myList

# %%
# input()함수는 키보드로 부터 입력
data = input()
print('영화제목 : ' + data)

# %%
# 키보드로부터 입력을 받아서 변수에 전달하는 함수
a = input('life is short')
a

# %%
# input()함수는 키보드로부터 입력
data = input()
type(data)

# %%
type(data)

# %%
myList =[]
data = input()
myList.append(data)
data = input()
myList.append(data)
myList

# %%
# insert 함수는 내가 위치를 지정할때 사용하는 함수
myList = [1,3,4]
myList.insert(1,2)
myList

# %% [markdown]
# #### 리스트에서 제거하기

# %%
mylist

# %%
mylist.remove(1)  #remove 함수에 동일한 인자가 있을 때 앞에걸 지운다.

# %%
mylist

# %%
mylist.remove(1)

# %% [markdown]
# ### pop()은 리스트의 맨 마지막 요소를 리턴하고 그 요소는 삭제한다.

# %%
myList = [1,2,3,4,5]
returnValue1 = myList.pop()
print(returnValue1)
returnValue2 = myList.pop()
returnValue2

# %% [markdown]
# #### 여러 값들이 포함되어 있을 때 제거 순서

# %%
mylist = []
mylist.append(1)
mylist.append(2)
mylist.append(3)
mylist.append(1)
mylist.append(2)
mylist.append(3)

# %%
mylist
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
mylist.remove(1)

# %%
mylist
# Out:
# [2, 3, 1, 2, 3]

# %%
mylist.remove(1)

# %%
mylist
# Out:
# [2, 3, 2, 3]

# %%
mylist.remove(1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-c90a6cab05e0> in <cell line: 1>()
# ----> 1 mylist.remove(1)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# #### 인덱싱(indexing) -> 색인

# %%
mylist = [1, 2, 3, 4]

# %% [markdown]
# 인덱스는 **0번 부터 시작** 합니다.

# %%
mylist[0]

# %%
mylist[3]

# %%
mylist[4]

# %%
mylist = [1, 2, 3, 4]

# %%
mylist[-2]

# %%
# -는 뒤에서
mylist[-5]

# %% [markdown]
# #### 인덱스로 접근하여 값 바꾸기

# %%
mylist

# %%
mylist[0]

# %%
# 0번 인덱스의 데이터를 100으로 덮어쓰기
mylist[0] = 100

# %%
mylist

# %% [markdown]
# #### 전체 길이 (사이즈) 알아내기

# %%
len(mylist)

# %%
a = [1,2,3]
#리스트에서 하나씩 꺼내서 i변수에 전달하고, 하나씩 출력
for i in a :
  print(i)

# %%
# 1~10까지 값을 리스트로 넣어주고, 그 값을 for문으로 출력
myList = []
myList.append(1)
myList.append(2)
myList.append(3)
myList.append(4)
myList.append(5)
myList.append(6)
myList.append(7)
myList.append(8)
myList.append(9)
myList.append(10)
print(myList)

for i in myList :
  print(i)

# %%
# 잠깐 for문 미리 활용해서 코딩
# 시작값이 1이고, 종료조건이 10미만이고, 증가분이 1씩 증가
myList = []

for i in range(1,100):
    myList.append(i)

myList
len(myList)
# Out:
# 99

# %% [markdown]
# ## *활용*: 파일 4개를 생성하고, 파일의 목록을 리스트에 받아오는

# %%
startValue = 1
stopValue = 11
a = []

for i in range(startValue,stopValue):
  a.append(i)

#print(a)

for i in a :
  print(i)

# %% [markdown]
# ##활용: 파일 4개를 생성하고, 파일의 목록을 리스트에 받아오는

# %%
# LS명령은 리눅스 명령어이고, ls(list)
# !ls

# %%
# 리눅스 명령어인 touch를 이용해서 내용이 아무것도 없는 a.txt파일을 만듭니다.
# !touch a.txt b.txt c.txt d.txt

# %%
# 현재 폴더에 빈파일들을 4개 만들기

# colab이 실행되는 서버의 os가 linux
# '!'는 터미널 명령 ls(list)
# -al은 리눅스 명령어로 전부다 보여줌 '.Config'등등
# !ls

# %%
import os
# os(패키지) 현재 작업 디렉토리(working floder)의 파일 목록들을 가져옴
filenames = os.listdir()
filenames

# %%
removeList1 = filenames[0]
removeList2 = filenames[5]

# %%
# filenames라는 리스트에서 '.config'와 'sample_data'를 삭제하고 txt파일만 남길때
filenames.remove(removeList1)
filenames.remove(removeList2)
filenames

# %%
# 만약 내가 찾고자하는 파일을 골라서 리스트로 만들때 아주 편하게 사용가능
import glob

dirPath = '/content/newFolder/*.txt'
glob.glob('./*')  #['./b.txt', './c.txt', './d.txt', './newFolder', './a.txt', './sample_data']  경로를 이야기함. 뜻= .현재경로 /밑에 있는 *모든파일들
#glob.glob(dirPath) #['/content/newFolder/1.txt']

# %% [markdown]
# ## 리스트 활용해서 폴더의 파일명을 읽어오는 코드

# %% [markdown]
# ### 4-2. tuple (순서가 있는 집합, 읽기 전용, 원본데이터에 변경이 없을경우에 사용하면 좋음)

# %% [markdown]
# () 로 표현합니다

# %%
myTuple = (1, 2, 3, 4, 5)

# %%
myTuple.append(1)

# %%
myTuple.remove(1)

# %%
myTuple[0] = 1

# %% [markdown]
# #### 길이 파악하기

# %%
len(myTuple)

# %%
myTuple

# %% [markdown]
# ## set (순서 X, 중복 X = 얜 걍 집합임)

# %%
myset = set()

# %%
myset

# %%
type(myset)

# %%
myset.add(1)
myset.add(2)
myset.add(3)

# %%
myset

# %%
myset.add(1)
myset.add(2)
myset.add(3)
myset.add(1)
myset.add(2)
myset.add(3)

# %%
myset #중복 추가 안됨 + 여러개 더할 때는 (update)

# %%
myset.add(4) # 없는걸 넣는건 ㅇㅋ

# %%
myset

# %%
len(myset)

# %% [markdown]
# ### 4-3. dict (사전형 집합, key와 value 쌍)

# %% [markdown]
# {}로 표현합니다

# %%
mydict = dict()

# %%
mydict

# %%
type(mydict)

# %% [markdown]
# #### 값을 추가하기

# %%
mydict = dict()

# %%
# key값이 'apple', value가 123456
mydict['apple'] = 123456

# %%
mydict['apple']

# %%
mydict[0] = 2

# %%
mydict[0]

# %%
mydict

# %% [markdown]
# mydict의 키는 **문자형** / **숫자형**이 혼용 가능합니다

# %%
mydict

# %% [markdown]
# float(실수)도 키로써 입력이 가능합니다.

# %%
mydict[3.14] = 1

# %%
mydict

# %% [markdown]
# #### 값을 바꾸기

# %%
mydict['apple'] = 'byebye'

# %%
mydict

# %% [markdown]
# #### 길이 파악하기

# %%
len(mydict)

# %% [markdown]
# # 주사위를 원하는 횟수만큼 던지고 그 결과값을 리스트로 저장

# %%
import random
myList = []

#1. 키보드로부터 반복 횟수를 입력 받는다.
count = input()

# 2. 타입을 확인한다(str)
print(type(count))

#3. 타입을 'str' -> 'int'로 변경한다.
count = int(count)
print(type(count))

#4. 반복 횟수만큼 난수(1~6사이의)를 생성해서 리스트에 추가해준다.
for i in range(10):
  num = random.randrange(1,7)
  myList.append(num)

print(myList)
